# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
k0 = pd.read_csv("E:/Pareto Optimization Data/H_0.50/ATT_TransposedAverage.csv", delimiter=',')
k0
# Out:
#    CAVPenetrationPercentage       TSTT1       TSTT2       TSTT3  AverageTSTT  \
# 0                        0%  2321645.25  2893923.85  2888612.25  2701393.783
# 1                       10%  2558342.70  2743392.60  2749510.35  2683748.550
# 2                       20%  2713177.15  2715184.50  2641378.75  2689913.467
# 3                       30%  2526322.55  2574881.45  2513481.15  2538228.383
# 4                       40%  2415395.40  2417921.55  2452199.40  2428505.450
# 5                       50%  2419687.75  2406963.30  2389875.15  2405508.733
# 6                       60%  2362090.65  2364523.75  2362611.10  2363075.167
# 7                       70%  2328151.40  2340468.90  2347297.85  2338639.383
# 8                       80%  2311263.65  2334215.10  2334632.65  2326703.800
# 9                       90%  2307960.05  2319817.85  2327112.15  2318296.683
# 10                     100%  2290289.75  2303556.30  2287970.65  2293938.900
#
# ...

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot("CAVPenetrationPercentage", "TSTT1",data = k0)
plt.plot("CAVPenetrationPercentage", "TSTT2",data = k0)
plt.plot("CAVPenetrationPercentage", "TSTT3",data = k0)
plt.plot("CAVPenetrationPercentage", "AverageTSTT",data = k0)
 
ax.legend(['TSTT seed1', 'TSTT seed2', 'TSTT seed3', 'Average TSTT'], facecolor='w')
#ax.set_title('Kernel Densty estimation of DeltaS Seed3')
plt.xticks(np.arange(0, 11, step=1),rotation=45)
#plt.yticks(np.arange(0, 11, step=1),rotation=45)
ax.set_ylabel('Total System travel time(TSTT)')
ax.set_xlabel('CAV Penetration Percentage')
plt.show()
#plt.savefig('C:/Users/z5130037/OneDrive - UNSW/CAVSeverityResults/D0_results/InputData/DeltaS_Seed3.png')

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot("CAVPenetrationPercentage", 'AverageTSTT', data=k0)
ax.legend(['Average TSTT'], facecolor='w')
plt.xticks(np.arange(0, 11, step=1),rotation=45)
#plt.xticks(np.arange(0, 11, step=1),rotation=45)
ax.set_xlabel('CAV Penetration Percentage')
ax.set_ylabel('Total System travel time(TSTT)')
#ax.set_title('Seed3')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot("CAVPenetrationPercentage", "DelayTotal1",data = k0)
plt.plot("CAVPenetrationPercentage", "DelayTotal2",data = k0)
plt.plot("CAVPenetrationPercentage", "DelayTotal3",data = k0)
plt.plot("CAVPenetrationPercentage", "AverageDelayTotal",data = k0)
 
ax.legend(['DelayTotal seed1', 'DelayTotal seed2', 'DelayTotal seed3', 'Average DelayTotal'], facecolor='w')
#ax.set_title('Kernel Densty estimation of DeltaS Seed3')
plt.xticks(np.arange(0, 11, step=1),rotation=45)
#plt.yticks(np.arange(0, 11, step=1),rotation=45)
ax.set_ylabel('Total Delay')
ax.set_xlabel('CAV Penetration Percentage')
plt.show()
#plt.savefig('C:/Users/z5130037/OneDrive - UNSW/CAVSeverityResults/D0_results/InputData/DeltaS_Seed3.png')

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot("CAVPenetrationPercentage", 'AverageDelayTotal', data=k0)
ax.legend(['Average DelayTotal'], facecolor='w')
plt.xticks(np.arange(0, 11, step=1),rotation=45)
#plt.xticks(np.arange(0, 11, step=1),rotation=45)
ax.set_xlabel('CAV Penetration Percentage')
ax.set_ylabel('Total Delay')
#ax.set_title('Seed3')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot("CAVPenetrationPercentage", "AverageSpeed1",data = k0)
plt.plot("CAVPenetrationPercentage", "AverageSpeed2",data = k0)
plt.plot("CAVPenetrationPercentage", "AverageSpeed3",data = k0)
plt.plot("CAVPenetrationPercentage", "AverageAverageSpeed",data = k0)
 
ax.legend(['Average Speed for seed1', 'Average Speed for seed2', 'Average Speed for seed3', 'Overall Average Speed '], facecolor='w')
#ax.set_title('Kernel Densty estimation of DeltaS Seed3')
plt.xticks(np.arange(0, 11, step=1),rotation=45)
#plt.yticks(np.arange(0, 11, step=1),rotation=45)
ax.set_ylabel('Average Speed (km/hr)')
ax.set_xlabel('CAV Penetration Percentage')
plt.show()
#plt.savefig('C:/Users/z5130037/OneDrive - UNSW/CAVSeverityResults/D0_results/InputData/DeltaS_Seed3.png')

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot("CAVPenetrationPercentage", 'AverageAverageSpeed', data=k0)
ax.legend(['Overall Average Speed'], facecolor='w')
plt.xticks(np.arange(0, 11, step=1),rotation=45)
#plt.xticks(np.arange(0, 11, step=1),rotation=45)
ax.set_xlabel('CAV Penetration Percentage')
ax.set_ylabel('Average Speed (km/hr)')
#ax.set_title('Seed3')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot("CAVPenetrationPercentage", 'FinalDelay', data=k0)
ax.legend(['Effective Delay'], facecolor='w')
plt.xticks(np.arange(0, 11, step=1),rotation=45)
#plt.xticks(np.arange(0, 11, step=1),rotation=45)
ax.set_xlabel('CAV Penetration Percentage')
ax.set_ylabel('Effective Delay')
#ax.set_title('Seed3')
plt.show()
