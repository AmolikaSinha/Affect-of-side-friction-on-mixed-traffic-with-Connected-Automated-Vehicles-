# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
# Out:
#         Time   Link  Lane   VehNo  VehType  Line  DesSpeed
# 0        0.6    3.0   1.0     1.0    101.0   0.0       5.7
# 1        0.9   53.0   1.0     2.0    101.0   0.0       5.4
# 2        0.4  306.0   1.0     3.0    100.0   0.0       4.3
# 3        1.3  414.0   1.0     4.0    100.0   0.0       5.2
# 4        1.9  614.0   1.0     5.0    101.0   0.0       5.0
# ...      ...    ...   ...     ...      ...   ...       ...
# 1862  1611.3  203.0   2.0  1847.0    101.0   0.0       5.1
# 1863  1612.1  414.0   2.0  1878.0    100.0   0.0       4.1
# 1864  1613.8  464.0   2.0  1879.0    100.0   0.0       5.1
# 1865  1615.1    3.0   2.0  1880.0    101.0   0.0       4.1
# 1866  1615.7  614.0   2.0  1881.0    101.0   0.0       4.3
#
# [1867 rows x 7 columns]

# %% [markdown]
# counts = df['VehType'].value_counts()

# %% [markdown]
# counts

# %% [markdown]
# # Enter the address of fhz file to corresponding rows (Manual Buses)

# %%
HB_0 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
HB_10 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#HB_20 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
HB_30 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#HB_40 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
HB_50 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#HB_60 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
HB_70 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#HB_80 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
HB_90 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
HB_100 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)

# %%
count_HB_0 = HB_0['VehType'].value_counts()
count_HB_10 = HB_10['VehType'].value_counts()
#count_HB_20 = HB_20['VehType'].value_counts()
count_HB_30 = HB_30['VehType'].value_counts()
#count_HB_40 = HB_40['VehType'].value_counts()
count_HB_50 = HB_50['VehType'].value_counts()
#count_HB_60 = HB_60['VehType'].value_counts()
count_HB_70 = HB_70['VehType'].value_counts()
#count_HB_80 = HB_80['VehType'].value_counts()
count_HB_90 = HB_90['VehType'].value_counts()
count_HB_100 = HB_100['VehType'].value_counts()

# %%
print("0% with Human buses")
print(count_HB_0)
print("**********************************************************************************************")

print("10% with Human buses")
print(count_HB_10)
print("**********************************************************************************************")

#print("20% with Human buses")
#print(count_HB_20)
#print("**********************************************************************************************")

print("30% with Human buses")
print(count_HB_30)
print("**********************************************************************************************")

#print("40% with Human buses")
#print(count_HB_40)
#print("**********************************************************************************************")

print("50% with Human buses")
print(count_HB_50)
print("**********************************************************************************************")

#print("60% with Human buses")
#print(count_HB_60)
#print("**********************************************************************************************")

print("70% with Human buses")
print(count_HB_70)
print("**********************************************************************************************")

#print("80% with Human buses")
#print(count_HB_80)
#print("**********************************************************************************************")

print("90% with Human buses")
print(count_HB_90)
print("**********************************************************************************************")

print("100% with Human buses")
print(count_HB_100)
print("**********************************************************************************************")
# Out:
# 0% with Human buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 10% with Human buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 30% with Human buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 50% with Human buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 70% with Human buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 90% with Human buses
# ...

# %% [markdown]
# # Enter the address of fhz file to corresponding rows (Autonomous buses)

# %%
AB_0 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
AB_10 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#AB_20 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
AB_30 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#AB_40 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
AB_50 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#AB_60 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
AB_70 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
#AB_80 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
AB_90 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)
AB_100 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Sample_Data\3x3_001_fhz.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed'], dtype = {'Time' : float , 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1, index_col=False)

# %%
count_AB_0 = AB_0['VehType'].value_counts()
count_AB_10 = AB_10['VehType'].value_counts()
#count_AB_20 = AB_20['VehType'].value_counts()
count_AB_30 = AB_30['VehType'].value_counts()
#count_AB_40 = AB_40['VehType'].value_counts()
count_AB_50 = AB_50['VehType'].value_counts()
#count_AB_60 = AB_60['VehType'].value_counts()
count_AB_70 = AB_70['VehType'].value_counts()
#count_AB_80 = AB_80['VehType'].value_counts()
count_AB_90 = AB_90['VehType'].value_counts()
count_AB_100 = AB_100['VehType'].value_counts()

# %%
print("0% with Autonomous buses")
print(count_AB_0)
print("**********************************************************************************************")

print("10% with Autonomous buses")
print(count_AB_10)
print("**********************************************************************************************")

#print("20% with Autonomous buses")
#print(count_AB_20)
#print("**********************************************************************************************")

print("30% with Autonomous buses")
print(count_AB_30)
print("**********************************************************************************************")

#print("40% with Autonomous buses")
#print(count_AB_40)
#print("**********************************************************************************************")

print("50% with Autonomous buses")
print(count_AB_50)
print("**********************************************************************************************")

#print("60% with Autonomous buses")
#print(count_AB_60)
#print("**********************************************************************************************")

print("70% with Autonomous buses")
print(count_AB_70)
print("*********************************************************************************************")

#print("80% with Autonomous buses")
#print(count_AB_80)
#print("**********************************************************************************************")

print("90% with Autonomous buses")
print(count_AB_90)
print("**********************************************************************************************")

print("100% with Autonomous buses")
print(count_AB_100)
print("**********************************************************************************************")
# Out:
# 0% with Autonomous buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 10% with Autonomous buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 30% with Autonomous buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 50% with Autonomous buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# **********************************************************************************************
# 70% with Autonomous buses
# 101.0    914
# 100.0    863
# 301.0     90
# Name: VehType, dtype: int64
# *********************************************************************************************
# ...

# %% [markdown]
# # Demand Calculation from Throughput
