# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
# %matplotlib inline

# %%
import sklearn.datasets
import seaborn as sns

# %% [markdown]
# BUS_0 = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Codes\Plots_heatmaps\collission_segregation.csv', delimiter = ',', header = 0)
# BUS_0_MV_MV = ((BUS_0.loc[BUS_0['Interaction_Type'] == 'MV-MV']))
# print(len(BUS_0_MV_MV))
# print(type(BUS_0_MV_MV))
# #print(len((BUS_0_MV_MV["FirstVID"]).unique()))
# BUS_0_MV_MV = (BUS_0_MV_MV.drop_duplicates(subset=['FirstVID']))
# print(len(BUS_0_MV_MV))
# print(type(BUS_0_MV_MV))

# %% [markdown]
# fig, ax = plt.subplots(figsize=(6,6))
# sns.kdeplot(BUS_0_MV_MV["PET"],clip=(0,100), gridsize = 200,cut=0)
#
#
#
# #ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
# ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')
#
# #ax.set_title('Kernel Densty estimation of DeltaS Seed1')
# ax.set_title('Mv-MV (Human Driven Buses)')
# ax.set_xlabel('PET')
# ####ax.set_ylim([0,1.2]) # fix this in the end
# plt.show()
# ax.set_title('Kernel Densty estimation of PET')

# %% [markdown]
# print((BUS_0_MV_MV))

# %%
BUS_0 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_HB\0%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
BUS_10 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_HB\10%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
BUS_30 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_HB\30%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
BUS_50 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_HB\50%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
BUS_70 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_HB\70%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
BUS_90 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_HB\90%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
AB_0 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_AB\0%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
AB_10 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_AB\10%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
AB_30 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_AB\30%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
AB_50 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_AB\50%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
AB_70 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_AB\70%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
AB_90 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_AB\90%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)
AB_100 = pd.read_csv(r'C:\Users\maxin\Desktop\Randwick_Results\AV_AB\100%\Result\SSAM_V2\collission_segregation.csv', delimiter = ',', header = 0)

# %%
#0% BUS
BUS_0_MV_MV = ((BUS_0.loc[BUS_0['Interaction_Type'] == 'MV-MV']))
BUS_0_MV_MV = (BUS_0_MV_MV.drop_duplicates(subset=['FirstVID']))

BUS_0_BUS_BUS = (BUS_0.loc[BUS_0['Interaction_Type'] == 'BUS-BUS'])
BUS_0_BUS_BUS = (BUS_0_BUS_BUS.drop_duplicates(subset=['FirstVID']))

BUS_0_CAV_CAV = (BUS_0.loc[BUS_0['Interaction_Type'] == 'AV-AV'])
BUS_0_CAV_CAV = (BUS_0_CAV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_0_MV_CAV = (BUS_0.loc[BUS_0['Interaction_Type'] == 'MV-AV'])
BUS_0_MV_CAV = (BUS_0_MV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_0_CAV_MV = (BUS_0.loc[BUS_0['Interaction_Type'] == 'AV-MV'])
BUS_0_CAV_MV = (BUS_0_CAV_MV.drop_duplicates(subset=['FirstVID']))

BUS_0_MV_BUS = (BUS_0.loc[BUS_0['Interaction_Type'] == 'MV-BUS'])
BUS_0_MV_BUS = (BUS_0_MV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_0_BUS_MV = (BUS_0.loc[BUS_0['Interaction_Type'] == 'BUS-MV'])
BUS_0_BUS_MV = (BUS_0_BUS_MV.drop_duplicates(subset=['FirstVID']))

BUS_0_CAV_BUS = (BUS_0.loc[BUS_0['Interaction_Type'] == 'AV-BUS'])
BUS_0_CAV_BUS = (BUS_0_CAV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_0_BUS_CAV = (BUS_0.loc[BUS_0['Interaction_Type'] == 'BUS-AV'])
BUS_0_BUS_CAV = (BUS_0_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((BUS_0).unique())
#print(BUS_0_MV_MV+BUS_0_BUS_BUS+BUS_0_CAV_CAV+BUS_0_MV_CAV+BUS_0_CAV_MV+BUS_0_MV_BUS+BUS_0_BUS_MV+BUS_0_CAV_BUS+BUS_0_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#10% BUS
BUS_10_MV_MV = ((BUS_10.loc[BUS_10['Interaction_Type'] == 'MV-MV']))
BUS_10_MV_MV = (BUS_10_MV_MV.drop_duplicates(subset=['FirstVID']))

BUS_10_BUS_BUS = (BUS_10.loc[BUS_10['Interaction_Type'] == 'BUS-BUS'])
BUS_10_BUS_BUS = (BUS_10_BUS_BUS.drop_duplicates(subset=['FirstVID']))

BUS_10_CAV_CAV = (BUS_10.loc[BUS_10['Interaction_Type'] == 'AV-AV'])
BUS_10_CAV_CAV = (BUS_10_CAV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_10_MV_CAV = (BUS_10.loc[BUS_10['Interaction_Type'] == 'MV-AV'])
BUS_10_MV_CAV = (BUS_10_MV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_10_CAV_MV = (BUS_10.loc[BUS_10['Interaction_Type'] == 'AV-MV'])
BUS_10_CAV_MV = (BUS_10_CAV_MV.drop_duplicates(subset=['FirstVID']))

BUS_10_MV_BUS = (BUS_10.loc[BUS_10['Interaction_Type'] == 'MV-BUS'])
BUS_10_MV_BUS = (BUS_10_MV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_10_BUS_MV = (BUS_10.loc[BUS_10['Interaction_Type'] == 'BUS-MV'])
BUS_10_BUS_MV = (BUS_10_BUS_MV.drop_duplicates(subset=['FirstVID']))

BUS_10_CAV_BUS = (BUS_10.loc[BUS_10['Interaction_Type'] == 'AV-BUS'])
BUS_10_CAV_BUS = (BUS_10_CAV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_10_BUS_CAV = (BUS_10.loc[BUS_10['Interaction_Type'] == 'BUS-AV'])
BUS_10_BUS_CAV = (BUS_10_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((BUS_10).unique())
#print(BUS_10_MV_MV+BUS_10_BUS_BUS+BUS_10_CAV_CAV+BUS_10_MV_CAV+BUS_10_CAV_MV+BUS_10_MV_BUS+BUS_10_BUS_MV+BUS_10_CAV_BUS+BUS_10_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#30% BUS
BUS_30_MV_MV = ((BUS_30.loc[BUS_30['Interaction_Type'] == 'MV-MV']))
BUS_30_MV_MV = (BUS_30_MV_MV.drop_duplicates(subset=['FirstVID']))

BUS_30_BUS_BUS = (BUS_30.loc[BUS_30['Interaction_Type'] == 'BUS-BUS'])
BUS_30_BUS_BUS = (BUS_30_BUS_BUS.drop_duplicates(subset=['FirstVID']))

BUS_30_CAV_CAV = (BUS_30.loc[BUS_30['Interaction_Type'] == 'AV-AV'])
BUS_30_CAV_CAV = (BUS_30_CAV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_30_MV_CAV = (BUS_30.loc[BUS_30['Interaction_Type'] == 'MV-AV'])
BUS_30_MV_CAV = (BUS_30_MV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_30_CAV_MV = (BUS_30.loc[BUS_30['Interaction_Type'] == 'AV-MV'])
BUS_30_CAV_MV = (BUS_30_CAV_MV.drop_duplicates(subset=['FirstVID']))

BUS_30_MV_BUS = (BUS_30.loc[BUS_30['Interaction_Type'] == 'MV-BUS'])
BUS_30_MV_BUS = (BUS_30_MV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_30_BUS_MV = (BUS_30.loc[BUS_30['Interaction_Type'] == 'BUS-MV'])
BUS_30_BUS_MV = (BUS_30_BUS_MV.drop_duplicates(subset=['FirstVID']))

BUS_30_CAV_BUS = (BUS_30.loc[BUS_30['Interaction_Type'] == 'AV-BUS'])
BUS_30_CAV_BUS = (BUS_30_CAV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_30_BUS_CAV = (BUS_30.loc[BUS_30['Interaction_Type'] == 'BUS-AV'])
BUS_30_BUS_CAV = (BUS_30_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((BUS_30).unique())
#print(BUS_30_MV_MV+BUS_30_BUS_BUS+BUS_30_CAV_CAV+BUS_30_MV_CAV+BUS_30_CAV_MV+BUS_30_MV_BUS+BUS_30_BUS_MV+BUS_30_CAV_BUS+BUS_30_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#50% BUS
BUS_50_MV_MV = ((BUS_50.loc[BUS_50['Interaction_Type'] == 'MV-MV']))
BUS_50_MV_MV = (BUS_50_MV_MV.drop_duplicates(subset=['FirstVID']))

BUS_50_BUS_BUS = (BUS_50.loc[BUS_50['Interaction_Type'] == 'BUS-BUS'])
BUS_50_BUS_BUS = (BUS_50_BUS_BUS.drop_duplicates(subset=['FirstVID']))

BUS_50_CAV_CAV = (BUS_50.loc[BUS_50['Interaction_Type'] == 'AV-AV'])
BUS_50_CAV_CAV = (BUS_50_CAV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_50_MV_CAV = (BUS_50.loc[BUS_50['Interaction_Type'] == 'MV-AV'])
BUS_50_MV_CAV = (BUS_50_MV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_50_CAV_MV = (BUS_50.loc[BUS_50['Interaction_Type'] == 'AV-MV'])
BUS_50_CAV_MV = (BUS_50_CAV_MV.drop_duplicates(subset=['FirstVID']))

BUS_50_MV_BUS = (BUS_50.loc[BUS_50['Interaction_Type'] == 'MV-BUS'])
BUS_50_MV_BUS = (BUS_50_MV_BUS.drop_duplicates(subset=['FirstVID'])

BUS_50_BUS_MV = (BUS_50.loc[BUS_50['Interaction_Type'] == 'BUS-MV'])
BUS_50_BUS_MV = (BUS_50_BUS_MV.drop_duplicates(subset=['FirstVID']))

BUS_50_CAV_BUS = (BUS_50.loc[BUS_50['Interaction_Type'] == 'AV-BUS'])
BUS_50_CAV_BUS = (BUS_50_CAV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_50_BUS_CAV = (BUS_50.loc[BUS_50['Interaction_Type'] == 'BUS-AV'])
BUS_50_BUS_CAV = (BUS_50_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((BUS_50).unique())
print(BUS_50_MV_MV+BUS_50_BUS_BUS+BUS_50_CAV_CAV+BUS_50_MV_CAV+BUS_50_CAV_MV+BUS_50_MV_BUS+BUS_50_BUS_MV+BUS_50_CAV_BUS+BUS_50_BUS_CAV)
print("Make sure that these two numbers are same")

# %%
#70% BUS
BUS_70_MV_MV = ((BUS_70.loc[BUS_70['Interaction_Type'] == 'MV-MV']))
BUS_70_MV_MV = (BUS_70_MV_MV.drop_duplicates(subset=['FirstVID']))

BUS_70_BUS_BUS = (BUS_70.loc[BUS_70['Interaction_Type'] == 'BUS-BUS'])
BUS_70_BUS_BUS = (BUS_70_BUS_BUS.drop_duplicates(subset=['FirstVID']))

BUS_70_CAV_CAV = (BUS_70.loc[BUS_70['Interaction_Type'] == 'AV-AV'])
BUS_70_CAV_CAV = (BUS_70_CAV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_70_MV_CAV = (BUS_70.loc[BUS_70['Interaction_Type'] == 'MV-AV'])
BUS_70_MV_CAV = (BUS_70_MV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_70_CAV_MV = (BUS_70.loc[BUS_70['Interaction_Type'] == 'AV-MV'])
BUS_70_CAV_MV = (BUS_70_CAV_MV.drop_duplicates(subset=['FirstVID']))

BUS_70_MV_BUS = (BUS_70.loc[BUS_70['Interaction_Type'] == 'MV-BUS'])
BUS_70_MV_BUS = (BUS_70_MV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_70_BUS_MV = (BUS_70.loc[BUS_70['Interaction_Type'] == 'BUS-MV'])
BUS_70_BUS_MV = (BUS_70_BUS_MV.drop_duplicates(subset=['FirstVID']))

BUS_70_CAV_BUS = (BUS_70.loc[BUS_70['Interaction_Type'] == 'AV-BUS'])
BUS_70_CAV_BUS = (BUS_70_CAV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_70_BUS_CAV = (BUS_70.loc[BUS_70['Interaction_Type'] == 'BUS-AV'])
BUS_70_BUS_CAV = (BUS_70_BUS_CAV.drop_duplicates(subset=['FirstVID']))

print(len((BUS_70).unique())
print(BUS_70_MV_MV+BUS_70_BUS_BUS+BUS_70_CAV_CAV+BUS_70_MV_CAV+BUS_70_CAV_MV+BUS_70_MV_BUS+BUS_70_BUS_MV+BUS_70_CAV_BUS+BUS_70_BUS_CAV)
print("Make sure that these two numbers are same")

# %%
#90% BUS
BUS_90_MV_MV = ((BUS_90.loc[BUS_90['Interaction_Type'] == 'MV-MV']))
BUS_90_MV_MV = (BUS_90_MV_MV.drop_duplicates(subset=['FirstVID']))

BUS_90_BUS_BUS = (BUS_90.loc[BUS_90['Interaction_Type'] == 'BUS-BUS'])
BUS_90_BUS_BUS = (BUS_90_BUS_BUS.drop_duplicates(subset=['FirstVID']))

BUS_90_CAV_CAV = (BUS_90.loc[BUS_90['Interaction_Type'] == 'AV-AV'])
BUS_90_CAV_CAV = (BUS_90_CAV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_90_MV_CAV = (BUS_90.loc[BUS_90['Interaction_Type'] == 'MV-AV'])
BUS_90_MV_CAV = (BUS_90_MV_CAV.drop_duplicates(subset=['FirstVID']))

BUS_90_CAV_MV = (BUS_90.loc[BUS_90['Interaction_Type'] == 'AV-MV'])
BUS_90_CAV_MV = (BUS_90_CAV_MV.drop_duplicates(subset=['FirstVID']))

BUS_90_MV_BUS = (BUS_90.loc[BUS_90['Interaction_Type'] == 'MV-BUS'])
BUS_90_MV_BUS = (BUS_90_MV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_90_BUS_MV = (BUS_90.loc[BUS_90['Interaction_Type'] == 'BUS-MV'])
BUS_90_BUS_MV = (BUS_90_BUS_MV.drop_duplicates(subset=['FirstVID']))

BUS_90_CAV_BUS = (BUS_90.loc[BUS_90['Interaction_Type'] == 'AV-BUS'])
BUS_90_CAV_BUS = (BUS_90_CAV_BUS.drop_duplicates(subset=['FirstVID']))

BUS_90_BUS_CAV = (BUS_90.loc[BUS_90['Interaction_Type'] == 'BUS-AV'])
BUS_90_BUS_CAV = (BUS_90_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((BUS_90).unique())
print(BUS_90_MV_MV+BUS_90_BUS_BUS+BUS_90_CAV_CAV+BUS_90_MV_CAV+BUS_90_CAV_MV+BUS_90_MV_BUS+BUS_90_BUS_MV+BUS_90_CAV_BUS+BUS_90_BUS_CAV)
print("Make sure that these two numbers are same")

# %%
#MV_MV PET **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_MV_MV["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Mv-MV (Human Driven Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#CAV-MV PET **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_CAV_MV["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-MV (Human Driven Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#Bus-MV PET **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_Bus_MV["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_Bus_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_Bus_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_Bus_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_Bus_MV["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Bus-MV (Human Driven Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#"Bus-Bus" **

fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_Bus_Bus["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_Bus_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_Bus_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_Bus_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_Bus_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Bus-Bus (Human Driven Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#"MV-Bus" **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_MV_Bus["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_MV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_MV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_MV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_MV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('MV-Bus (Human Driven Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#"CAV-Bus" **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_CAV_Bus["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_CAV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_CAV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_CAV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_CAV_Bus["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-Bus (Human Driven Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#MV_MV TTC

fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_MV_MV["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Mv-MV (Human Driven Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#CAV-MV TTC

fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_CAV_MV["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-MV (Human Driven Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#Bus-MV TTC
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_Bus_MV["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_Bus_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_Bus_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_Bus_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_Bus_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Bus-MV (Human Driven Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#"Bus-Bus" TTC
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_Bus_Bus["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_Bus_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_Bus_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_Bus_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_Bus_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Bus-Bus (Human Driven Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#"MV-Bus" TTC
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_MV_Bus["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_MV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_MV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_MV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_MV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('MV-Bus (Human Driven Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#"CAV-Bus" TTC
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_CAV_Bus["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_CAV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_CAV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_CAV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_CAV_Bus["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-Bus (Human Driven Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#MV_MV DeltaS Filter

BUS_10_MV_MV = ((BUS_10_MV_MV.loc[BUS_10_MV_MV['PET'] == 0]))
BUS_30_MV_MV = ((BUS_30_MV_MV.loc[BUS_30_MV_MV['PET'] == 0]))
BUS_50_MV_MV = ((BUS_50_MV_MV.loc[BUS_50_MV_MV['PET'] == 0]))
BUS_70_MV_MV = ((BUS_70_MV_MV.loc[BUS_70_MV_MV['PET'] == 0]))
BUS_90_MV_MV = ((BUS_90_MV_MV.loc[BUS_90_MV_MV['PET'] == 0]))

# %%
#MV_MV DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_MV_MV["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Mv-MV (Human Driven Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %%
#CAV-MV DeltaS Filter
BUS_10_CAV_MV = ((BUS_10_CAV_MV.loc[BUS_10_CAV_MV['PET'] == 0]))
BUS_30_CAV_MV = ((BUS_30_CAV_MV.loc[BUS_30_CAV_MV['PET'] == 0]))
BUS_50_CAV_MV = ((BUS_50_CAV_MV.loc[BUS_50_CAV_MV['PET'] == 0]))
BUS_70_CAV_MV = ((BUS_70_CAV_MV.loc[BUS_70_CAV_MV['PET'] == 0]))
BUS_90_CAV_MV = ((BUS_90_CAV_MV.loc[BUS_90_CAV_MV['PET'] == 0]))

# %%
#CAV-MV DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-MV (Human Driven Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %%
#Bus-MV DeltaS filter

BUS_10_Bus_MV = ((BUS_10_Bus_MV.loc[BUS_10_Bus_MV['PET'] == 0]))
BUS_30_Bus_MV = ((BUS_30_Bus_MV.loc[BUS_30_Bus_MV['PET'] == 0]))
BUS_50_Bus_MV = ((BUS_50_Bus_MV.loc[BUS_50_Bus_MV['PET'] == 0]))
BUS_70_Bus_MV = ((BUS_70_Bus_MV.loc[BUS_70_Bus_MV['PET'] == 0]))
BUS_90_Bus_MV = ((BUS_90_Bus_MV.loc[BUS_90_Bus_MV['PET'] == 0]))

# %%
#Bus-MV DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_Bus_MV["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_Bus_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_Bus_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_Bus_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_Bus_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Bus-MV (Human Driven Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %%
#"Bus-Bus" DeltaS Filter

BUS_10_Bus_Bus = ((BUS_10_Bus_Bus.loc[BUS_10_Bus_Bus['PET'] == 0]))
BUS_30_Bus_Bus = ((BUS_30_Bus_Bus.loc[BUS_30_Bus_Bus['PET'] == 0]))
BUS_50_Bus_Bus = ((BUS_50_Bus_Bus.loc[BUS_50_Bus_Bus['PET'] == 0]))
BUS_70_Bus_Bus = ((BUS_70_Bus_Bus.loc[BUS_70_Bus_Bus['PET'] == 0]))
BUS_90_Bus_Bus = ((BUS_90_Bus_Bus.loc[BUS_90_Bus_Bus['PET'] == 0]))

# %%
#"Bus-Bus" DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_Bus_Bus["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_Bus_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_Bus_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_Bus_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_Bus_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('Bus-Bus (Human Driven Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %%
#"MV-Bus"  DeltaS Filter

BUS_10_MV_Bus = ((BUS_10_MV_Bus.loc[BUS_10_MV_Bus['PET'] == 0]))
BUS_30_MV_Bus = ((BUS_30_MV_Bus.loc[BUS_30_MV_Bus['PET'] == 0]))
BUS_50_MV_Bus = ((BUS_50_MV_Bus.loc[BUS_50_MV_Bus['PET'] == 0]))
BUS_70_MV_Bus = ((BUS_70_MV_Bus.loc[BUS_70_MV_Bus['PET'] == 0]))
BUS_90_MV_Bus = ((BUS_90_MV_Bus.loc[BUS_90_MV_Bus['PET'] == 0]))

# %%
#"MV-Bus"  DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_MV_Bus["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_MV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_MV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_MV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_MV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('MV-Bus (Human Driven Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %%
#"CAV-Bus"  DeltaS Filter

BUS_10_CAV_Bus = ((BUS_10_CAV_Bus.loc[BUS_10_CAV_Bus['PET'] == 0]))
BUS_30_CAV_Bus = ((BUS_30_CAV_Bus.loc[BUS_30_CAV_Bus['PET'] == 0]))
BUS_50_CAV_Bus = ((BUS_50_CAV_Bus.loc[BUS_50_CAV_Bus['PET'] == 0]))
BUS_70_CAV_Bus = ((BUS_70_CAV_Bus.loc[BUS_70_CAV_Bus['PET'] == 0]))
BUS_90_CAV_Bus = ((BUS_90_CAV_Bus.loc[BUS_90_CAV_Bus['PET'] == 0]))

# %%
#"CAV-Bus"  DeltaS

fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(BUS_10_CAV_Bus["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(BUS_30_CAV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_50_CAV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_70_CAV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(BUS_90_CAV_Bus["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-Bus (Human Driven Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %% [markdown]
# # CABs

# %%
#10% AB
AB_10_MV_MV = ((AB_10.loc[AB_10['Interaction_Type'] == 'MV-MV']))
AB_10_MV_MV = len(AB_10_MV_MV.drop_duplicates(subset=['FirstVID']))

AB_10_BUS_BUS = (AB_10.loc[AB_10['Interaction_Type'] == 'BUS-BUS'])
AB_10_BUS_BUS = len(AB_10_BUS_BUS.drop_duplicates(subset=['FirstVID']))

AB_10_CAV_CAV = (AB_10.loc[AB_10['Interaction_Type'] == 'AV-AV'])
AB_10_CAV_CAV = len(AB_10_CAV_CAV.drop_duplicates(subset=['FirstVID']))

AB_10_MV_CAV = (AB_10.loc[AB_10['Interaction_Type'] == 'MV-AV'])
AB_10_MV_CAV = len(AB_10_MV_CAV.drop_duplicates(subset=['FirstVID']))

AB_10_CAV_MV = (AB_10.loc[AB_10['Interaction_Type'] == 'AV-MV'])
AB_10_CAV_MV = len(AB_10_CAV_MV.drop_duplicates(subset=['FirstVID']))

AB_10_MV_BUS = (AB_10.loc[AB_10['Interaction_Type'] == 'MV-BUS'])
AB_10_MV_BUS = len(AB_10_MV_BUS.drop_duplicates(subset=['FirstVID']))

AB_10_BUS_MV = (AB_10.loc[AB_10['Interaction_Type'] == 'BUS-MV'])
AB_10_BUS_MV = len(AB_10_BUS_MV.drop_duplicates(subset=['FirstVID']))

AB_10_CAV_BUS = (AB_10.loc[AB_10['Interaction_Type'] == 'AV-BUS'])
AB_10_CAV_BUS = len(AB_10_CAV_BUS.drop_duplicates(subset=['FirstVID']))

AB_10_BUS_CAV = (AB_10.loc[AB_10['Interaction_Type'] == 'BUS-AV'])
AB_10_BUS_CAV = len(AB_10_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((AB_0).unique())
#print(AB_10_MV_MV+AB_10_BUS_BUS+AB_10_CAV_CAV+AB_10_MV_CAV+AB_10_CAV_MV+AB_10_MV_BUS+AB_10_BUS_MV+AB_10_CAV_BUS+AB_10_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#30% AB
AB_30_MV_MV = ((AB_30.loc[AB_30['Interaction_Type'] == 'MV-MV']))
AB_30_MV_MV = len(AB_30_MV_MV.drop_duplicates(subset=['FirstVID']))

AB_30_BUS_BUS = (AB_30.loc[AB_30['Interaction_Type'] == 'BUS-BUS'])
AB_30_BUS_BUS = len(AB_30_BUS_BUS.drop_duplicates(subset=['FirstVID']))

AB_30_CAV_CAV = (AB_30.loc[AB_30['Interaction_Type'] == 'AV-AV'])
AB_30_CAV_CAV = len(AB_30_CAV_CAV.drop_duplicates(subset=['FirstVID']))

AB_30_MV_CAV = (AB_30.loc[AB_30['Interaction_Type'] == 'MV-AV'])
AB_30_MV_CAV = len(AB_30_MV_CAV.drop_duplicates(subset=['FirstVID']))

AB_30_CAV_MV = (AB_30.loc[AB_30['Interaction_Type'] == 'AV-MV'])
AB_30_CAV_MV = len(AB_30_CAV_MV.drop_duplicates(subset=['FirstVID']))

AB_30_MV_BUS = (AB_30.loc[AB_30['Interaction_Type'] == 'MV-BUS'])
AB_30_MV_BUS = len(AB_30_MV_BUS.drop_duplicates(subset=['FirstVID']))

AB_30_BUS_MV = (AB_30.loc[AB_30['Interaction_Type'] == 'BUS-MV'])
AB_30_BUS_MV = len(AB_30_BUS_MV.drop_duplicates(subset=['FirstVID']))

AB_30_CAV_BUS = (AB_30.loc[AB_30['Interaction_Type'] == 'AV-BUS'])
AB_30_CAV_BUS = len(AB_30_CAV_BUS.drop_duplicates(subset=['FirstVID']))

AB_30_BUS_CAV = (AB_30.loc[AB_30['Interaction_Type'] == 'BUS-AV'])
AB_30_BUS_CAV = len(AB_30_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((AB_30).unique())
#print(AB_30_MV_MV+AB_30_BUS_BUS+AB_30_CAV_CAV+AB_30_MV_CAV+AB_30_CAV_MV+AB_30_MV_BUS+AB_30_BUS_MV+AB_30_CAV_BUS+AB_30_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#50% AB
AB_50_MV_MV = ((AB_50.loc[AB_50['Interaction_Type'] == 'MV-MV']))
AB_50_MV_MV = len(AB_50_MV_MV.drop_duplicates(subset=['FirstVID']))

AB_50_BUS_BUS = (AB_50.loc[AB_50['Interaction_Type'] == 'BUS-BUS'])
AB_50_BUS_BUS = len(AB_50_BUS_BUS.drop_duplicates(subset=['FirstVID']))

AB_50_CAV_CAV = (AB_50.loc[AB_50['Interaction_Type'] == 'AV-AV'])
AB_50_CAV_CAV = len(AB_50_CAV_CAV.drop_duplicates(subset=['FirstVID']))

AB_50_MV_CAV = (AB_50.loc[AB_50['Interaction_Type'] == 'MV-AV'])
AB_50_MV_CAV = len(AB_50_MV_CAV.drop_duplicates(subset=['FirstVID']))

AB_50_CAV_MV = (AB_50.loc[AB_50['Interaction_Type'] == 'AV-MV'])
AB_50_CAV_MV = len(AB_50_CAV_MV.drop_duplicates(subset=['FirstVID']))

AB_50_MV_BUS = (AB_50.loc[AB_50['Interaction_Type'] == 'MV-BUS'])
AB_50_MV_BUS = len(AB_50_MV_BUS.drop_duplicates(subset=['FirstVID']))

AB_50_BUS_MV = (AB_50.loc[AB_50['Interaction_Type'] == 'BUS-MV'])
AB_50_BUS_MV = len(AB_50_BUS_MV.drop_duplicates(subset=['FirstVID']))

AB_50_CAV_BUS = (AB_50.loc[AB_50['Interaction_Type'] == 'AV-BUS'])
AB_50_CAV_BUS = len(AB_50_CAV_BUS.drop_duplicates(subset=['FirstVID']))

AB_50_BUS_CAV = (AB_50.loc[AB_50['Interaction_Type'] == 'BUS-AV'])
AB_50_BUS_CAV = len(AB_50_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((AB_50).unique())
#print(AB_50_MV_MV+AB_50_BUS_BUS+AB_50_CAV_CAV+AB_50_MV_CAV+AB_50_CAV_MV+AB_50_MV_BUS+AB_50_BUS_MV+AB_50_CAV_BUS+AB_50_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#70% AB
AB_70_MV_MV = ((AB_70.loc[AB_70['Interaction_Type'] == 'MV-MV']))
AB_70_MV_MV = len(AB_70_MV_MV.drop_duplicates(subset=['FirstVID']))

AB_70_BUS_BUS = (AB_70.loc[AB_70['Interaction_Type'] == 'BUS-BUS'])
AB_70_BUS_BUS = len(AB_70_BUS_BUS.drop_duplicates(subset=['FirstVID']))

AB_70_CAV_CAV = (AB_70.loc[AB_70['Interaction_Type'] == 'AV-AV'])
AB_70_CAV_CAV = len(AB_70_CAV_CAV.drop_duplicates(subset=['FirstVID']))

AB_70_MV_CAV = (AB_70.loc[AB_70['Interaction_Type'] == 'MV-AV'])
AB_70_MV_CAV = len(AB_70_MV_CAV.drop_duplicates(subset=['FirstVID']))

AB_70_CAV_MV = (AB_70.loc[AB_70['Interaction_Type'] == 'AV-MV'])
AB_70_CAV_MV = len(AB_70_CAV_MV.drop_duplicates(subset=['FirstVID']))

AB_70_MV_BUS = (AB_70.loc[AB_70['Interaction_Type'] == 'MV-BUS'])
AB_70_MV_BUS = len(AB_70_MV_BUS.drop_duplicates(subset=['FirstVID']))

AB_70_BUS_MV = (AB_70.loc[AB_70['Interaction_Type'] == 'BUS-MV'])
AB_70_BUS_MV = len(AB_70_BUS_MV.drop_duplicates(subset=['FirstVID']))

AB_70_CAV_BUS = (AB_70.loc[AB_70['Interaction_Type'] == 'AV-BUS'])
AB_70_CAV_BUS = len(AB_70_CAV_BUS.drop_duplicates(subset=['FirstVID']))

AB_70_BUS_CAV = (AB_70.loc[AB_70['Interaction_Type'] == 'BUS-AV'])
AB_70_BUS_CAV = len(AB_70_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((AB_70).unique())
#print(AB_70_MV_MV+AB_70_BUS_BUS+AB_70_CAV_CAV+AB_70_MV_CAV+AB_70_CAV_MV+AB_70_MV_BUS+AB_70_BUS_MV+AB_70_CAV_BUS+AB_70_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#90% AB
AB_90_MV_MV = ((AB_90.loc[AB_90['Interaction_Type'] == 'MV-MV']))
AB_90_MV_MV = len(AB_90_MV_MV.drop_duplicates(subset=['FirstVID']))

AB_90_BUS_BUS = (AB_90.loc[AB_90['Interaction_Type'] == 'BUS-BUS'])
AB_90_BUS_BUS = len(AB_90_BUS_BUS.drop_duplicates(subset=['FirstVID']))

AB_90_CAV_CAV = (AB_90.loc[AB_90['Interaction_Type'] == 'AV-AV'])
AB_90_CAV_CAV = len(AB_90_CAV_CAV.drop_duplicates(subset=['FirstVID']))

AB_90_MV_CAV = (AB_90.loc[AB_90['Interaction_Type'] == 'MV-AV'])
AB_90_MV_CAV = len(AB_90_MV_CAV.drop_duplicates(subset=['FirstVID']))

AB_90_CAV_MV = (AB_90.loc[AB_90['Interaction_Type'] == 'AV-MV'])
AB_90_CAV_MV = len(AB_90_CAV_MV.drop_duplicates(subset=['FirstVID']))

AB_90_MV_BUS = (AB_90.loc[AB_90['Interaction_Type'] == 'MV-BUS'])
AB_90_MV_BUS = len(AB_90_MV_BUS.drop_duplicates(subset=['FirstVID']))

AB_90_BUS_MV = (AB_90.loc[AB_90['Interaction_Type'] == 'BUS-MV'])
AB_90_BUS_MV = len(AB_90_BUS_MV.drop_duplicates(subset=['FirstVID']))

AB_90_CAV_BUS = (AB_90.loc[AB_90['Interaction_Type'] == 'AV-BUS'])
AB_90_CAV_BUS = len(AB_90_CAV_BUS.drop_duplicates(subset=['FirstVID']))

AB_90_BUS_CAV = (AB_90.loc[AB_90['Interaction_Type'] == 'BUS-AV'])
AB_90_BUS_CAV = len(AB_90_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((AB_90).unique())
#print(AB_90_MV_MV+AB_90_BUS_BUS+AB_90_CAV_CAV+AB_90_MV_CAV+AB_90_CAV_MV+AB_90_MV_BUS+AB_90_BUS_MV+AB_90_CAV_BUS+AB_90_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#100% AB
AB_100_MV_MV = ((AB_100.loc[AB_100['Interaction_Type'] == 'MV-MV']))
AB_100_MV_MV = len(AB_100_MV_MV.drop_duplicates(subset=['FirstVID']))

AB_100_BUS_BUS = (AB_100.loc[AB_100['Interaction_Type'] == 'BUS-BUS'])
AB_100_BUS_BUS = len(AB_100_BUS_BUS.drop_duplicates(subset=['FirstVID']))

AB_100_CAV_CAV = (AB_100.loc[AB_100['Interaction_Type'] == 'AV-AV'])
AB_100_CAV_CAV = len(AB_100_CAV_CAV.drop_duplicates(subset=['FirstVID']))

AB_100_MV_CAV = (AB_100.loc[AB_100['Interaction_Type'] == 'MV-AV'])
AB_100_MV_CAV = len(AB_100_MV_CAV.drop_duplicates(subset=['FirstVID']))

AB_100_CAV_MV = (AB_100.loc[AB_100['Interaction_Type'] == 'AV-MV'])
AB_100_CAV_MV = len(AB_100_CAV_MV.drop_duplicates(subset=['FirstVID']))

AB_100_MV_BUS = (AB_100.loc[AB_100['Interaction_Type'] == 'MV-BUS'])
AB_100_MV_BUS = len(AB_100_MV_BUS.drop_duplicates(subset=['FirstVID']))

AB_100_BUS_MV = (AB_100.loc[AB_100['Interaction_Type'] == 'BUS-MV'])
AB_100_BUS_MV = len(AB_100_BUS_MV.drop_duplicates(subset=['FirstVID']))

AB_100_CAV_BUS = (AB_100.loc[AB_100['Interaction_Type'] == 'AV-BUS'])
AB_100_CAV_BUS = len(AB_100_CAV_BUS.drop_duplicates(subset=['FirstVID']))

AB_100_BUS_CAV = (AB_100.loc[AB_100['Interaction_Type'] == 'BUS-AV'])
AB_100_BUS_CAV = len(AB_100_BUS_CAV.drop_duplicates(subset=['FirstVID']))

#print(len((AB_100).unique())
#print(AB_100_MV_MV+AB_100_BUS_BUS+AB_100_CAV_CAV+AB_100_MV_CAV+AB_100_CAV_MV+AB_100_MV_BUS+AB_100_BUS_MV+AB_100_CAV_BUS+AB_100_BUS_CAV)
#print("Make sure that these two numbers are same")

# %%
#"MV-MV" **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_MV_MV["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_MV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('MV-MV (Connected automated Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#"CAV-MV" **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_CAV_MV["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_CAV_MV["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-MV (Connected automated Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#"CAB-MV" **
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_CAB_MV["PET"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_CAB_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_CAB_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_CAB_MV["PET"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_CAB_MV["PET"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAB-MV (Connected automated Buses)')
ax.set_xlabel('PET') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of PET')

# %%
#"MV-MV" TTC
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_MV_MV["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_MV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('MV-MV (Connected automated Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#"MV-MV" DeltaS filter

AB_10_MV_MV = ((AB_10_MV_MV.loc[AB_10_MV_MV['PET'] == 0]))
AB_30_MV_MV = ((AB_30_MV_MV.loc[AB_30_MV_MV['PET'] == 0]))
AB_50_MV_MV = ((AB_50_MV_MV.loc[AB_50_MV_MV['PET'] == 0]))
AB_70_MV_MV = ((AB_70_MV_MV.loc[AB_70_MV_MV['PET'] == 0]))
AB_90_MV_MV = ((AB_90_MV_MV.loc[AB_90_MV_MV['PET'] == 0]))

# %%
#"MV-MV" DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_MV_MV["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_MV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('MV-MV (Connected automated Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %%
#"CAV-MV" TTC
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_CAV_MV["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_CAV_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-MV (Connected automated Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#"CAV-MV"  DeltaS filter

AB_10_CAV_MV = ((AB_10_CAV_MV.loc[AB_10_CAV_MV['PET'] == 0]))
AB_30_CAV_MV = ((AB_30_CAV_MV.loc[AB_30_CAV_MV['PET'] == 0]))
AB_50_CAV_MV = ((AB_50_CAV_MV.loc[AB_50_CAV_MV['PET'] == 0]))
AB_70_CAV_MV = ((AB_70_CAV_MV.loc[AB_70_CAV_MV['PET'] == 0]))
AB_90_CAV_MV = ((AB_90_CAV_MV.loc[AB_90_CAV_MV['PET'] == 0]))

# %%
#"CAV-MV" DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_CAV_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAV-MV (Connected automated Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')

# %%
#"CAB-MV" TTC
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_CAB_MV["TTC"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_CAB_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_CAB_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_CAB_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_CAB_MV["TTC"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAB-MV (Connected automated Buses)')
ax.set_xlabel('TTC') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of TTC')

# %%
#"CAB-MV" DeltaS filter 

AB_10_CAB_MV = ((AB_10_CAB_MV.loc[AB_10_CAB_MV['PET'] == 0]))
AB_30_CAB_MV = ((AB_30_CAB_MV.loc[AB_30_CAB_MV['PET'] == 0]))
AB_50_CAB_MV = ((AB_50_CAB_MV.loc[AB_50_CAB_MV['PET'] == 0]))
AB_70_CAB_MV = ((AB_70_CAB_MV.loc[AB_70_CAB_MV['PET'] == 0]))
AB_90_CAB_MV = ((AB_90_CAB_MV.loc[AB_90_CAB_MV['PET'] == 0]))

# %%
#"CAB-MV" DeltaS
fig, ax = plt.subplots(figsize=(6,6))
sns.kdeplot(AB_10_CAB_MV["DeltaS"],clip=(0,100), gridsize = 200,cut=0)
sns.kdeplot(AB_30_CAB_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_50_CAB_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_70_CAB_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)
sns.kdeplot(AB_90_CAB_MV["DeltaS"],clip=(0,100), gridsize = 200, cut=0)


#ax.legend(['0% Penetration','10% Penetration','20% Penetration','30% Penetration','40% Penetration','50% Penetration','60% Penetration','70% Penetration','80% Penetration','90% Penetration','100% Penetration'], facecolor='w')
ax.legend(['10%', '30%', '50%', '70%','90%'], facecolor='w')

#ax.set_title('Kernel Densty estimation of DeltaS Seed1')
ax.set_title('CAB-MV (Connected automated Buses)')
ax.set_xlabel('DeltaS') 
####ax.set_ylim([0,1.2]) # fix this in the end
plt.show()
ax.set_title('Kernel Densty estimation of DeltaS')
