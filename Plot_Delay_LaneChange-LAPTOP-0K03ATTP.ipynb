# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Create some mock data
# t = np.arange(0.01, 10.0, 0.01)
# data1 = np.exp(t)
# data2 = np.sin(2 * np.pi * t)
#
# fig, ax1 = plt.subplots()
#
# color = 'tab:red'
# ax1.set_xlabel('time (s)')
# ax1.set_ylabel('exp', color=color)
# ax1.plot(t, data1, color=color)
# ax1.tick_params(axis='y', labelcolor=color)
#
# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
#
# color = 'tab:blue'
# ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
# ax2.plot(t, data2, color=color)
# ax2.tick_params(axis='y', labelcolor=color)
#
# fig.tight_layout()  # otherwise the right y-label is slightly clipped
# plt.show()

# %%
CAB = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Codes\Plots_heatmaps\CAB.csv', delimiter=",", dtype=float)
Bus = pd.read_csv(r'C:\Users\hp\OneDrive - UNSW\Honours student Sai\Danial\Codes\Plots_heatmaps\Bus.csv', delimiter=",", dtype=float)

# %%
print(min(Bus['Lane_Change']))
print(min(CAB['Lane_Change']))
LaneChangeLower = min(min(Bus['Lane_Change']), min(CAB['Lane_Change']))
print(LaneChangeLower)
LaneChangeLower = LaneChangeLower - (0.025*LaneChangeLower)


print(min(Bus['Dwell_Time']))
print(min(CAB['Dwell_Time']))
DwellTimeLower = min(min(Bus['Dwell_Time']), min(CAB['Dwell_Time']))
print(DwellTimeLower)
DwellTimeLower = DwellTimeLower - (0.025*DwellTimeLower)



print(max(Bus['Lane_Change']))
print(max(CAB['Lane_Change']))
LaneChangeHigh = max(max(Bus['Lane_Change']), max(CAB['Lane_Change']))
print(LaneChangeHigh)
LaneChangeHigh = LaneChangeHigh + (0.025*LaneChangeHigh)

print(max(Bus['Dwell_Time']))
print(max(CAB['Dwell_Time']))
DwellTimeHigh = max(max(Bus['Dwell_Time']), max(CAB['Dwell_Time']))
print(DwellTimeHigh)
DwellTimeHigh = DwellTimeHigh + (0.025*DwellTimeHigh)
# Out:
# 10.71095584
# 0.761927592
# 0.761927592
# 1.7058259619999998
# 3.061708261
# 1.7058259619999998
# 34.78262411
# 44.55627481
# 44.55627481
# 6.262147334
# 7.4361230670000005
# 7.4361230670000005

# %%
LN_CAB_1800 = CAB.loc[CAB['Time'] == 1800]
LN_CAB_1800 = LN_CAB_1800['Lane_Change']

LN_CAB_2700 = CAB.loc[CAB['Time'] == 2700]
LN_CAB_2700 = LN_CAB_2700['Lane_Change']

LN_CAB_3600 = CAB.loc[CAB['Time'] == 3600]
LN_CAB_3600 = LN_CAB_3600['Lane_Change']

LN_CAB_4500 = CAB.loc[CAB['Time'] == 4500]
LN_CAB_4500 = LN_CAB_4500['Lane_Change']
#LN_CAB_1800

# %%
LN_Bus_1800 = Bus.loc[Bus['Time'] == 1800]
LN_Bus_1800 = LN_Bus_1800['Lane_Change']

LN_Bus_2700 = Bus.loc[Bus['Time'] == 2700]
LN_Bus_2700 = LN_Bus_2700['Lane_Change']

LN_Bus_3600 = Bus.loc[Bus['Time'] == 3600]
LN_Bus_3600 = LN_Bus_3600['Lane_Change']

LN_Bus_4500 = Bus.loc[Bus['Time'] == 4500]
LN_Bus_4500 = LN_Bus_4500['Lane_Change']
#LN_CAB_1800

# %%
DL_CAB_1800 = CAB.loc[CAB['Time'] == 1800]
DL_CAB_1800 = DL_CAB_1800['Dwell_Time']

DL_CAB_2700 = CAB.loc[CAB['Time'] == 2700]
DL_CAB_2700 = DL_CAB_2700['Dwell_Time']

DL_CAB_3600 = CAB.loc[CAB['Time'] == 3600]
DL_CAB_3600 = DL_CAB_3600['Dwell_Time']

DL_CAB_4500 = CAB.loc[CAB['Time'] == 4500]
DL_CAB_4500 = DL_CAB_4500['Dwell_Time']

# %%
DL_Bus_1800 = Bus.loc[Bus['Time'] == 1800]
DL_Bus_1800 = DL_Bus_1800['Dwell_Time']

DL_Bus_2700 = Bus.loc[Bus['Time'] == 2700]
DL_Bus_2700 = DL_Bus_2700['Dwell_Time']

DL_Bus_3600 = Bus.loc[Bus['Time'] == 3600]
DL_Bus_3600 = DL_Bus_3600['Dwell_Time']

DL_Bus_4500 = Bus.loc[Bus['Time'] == 4500]
DL_Bus_4500 = DL_Bus_4500['Dwell_Time']

# %%
t = [0, 10, 30, 50, 70, 90, 100]
t
# Out:
# [0, 10, 30, 50, 70, 90, 100]

# %%
from matplotlib import rc
rc('mathtext', default='regular')

# %% [markdown]
# # 15 Minutes

# %%
fig1, ax1 = plt.subplots(figsize=(8,6))
#fig, ax1 = plt.subplots()

ax1.set_title("0-15 Minutes", fontweight = "bold", fontsize = 15)
#color = 'tab:red'
ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
#ax1.set_ylabel('Number of Lane Change', color=color)
ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
LN_CAB = ax1.plot(t, LN_CAB_1800, color="red", label = "CABs Network: Lane Change")
LN_Bus = ax1.plot(t, LN_Bus_1800, color="coral", label = "Bus Network: Lane Change")
#ax1.tick_params(axis='y', labelcolor=color)
ax1.tick_params(axis='y')
ax1.set_ylim(LaneChangeLower,LaneChangeHigh)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
#x2.set_ylabel('Dwell Time', color=color)
ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
DL_CAB = ax2.plot(t, DL_CAB_1800, color="blue", label = "CABs Network: Dwell Time")
DL_Bus = ax2.plot(t, DL_Bus_1800, color="aqua", label = "Bus Network: Dwell Time")

#ax2.tick_params(axis='y', labelcolor=color)
ax2.tick_params(axis='y', size=20)
ax2.set_ylim(DwellTimeLower,DwellTimeHigh)


# added these three lines
lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))


#ax1.legend(loc=0)
#ax2.legend(loc=4)

#ax1.legend()
#ax2.legend()

fig1.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %% [markdown]
# best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center

# %% [markdown]
# # 15-30 Minutes

# %%
fig2, ax1 = plt.subplots(figsize=(8,6))


ax1.set_title("15-30 Minutes", fontweight = "bold", fontsize = 15)
#color = 'tab:red'
ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
#ax1.set_ylabel('Number of Lane Change', color=color)
ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
LN_CAB = ax1.plot(t, LN_CAB_2700, color="red", label = "CABs Network: Lane Change")
LN_Bus = ax1.plot(t, LN_Bus_2700, color="coral", label = "Bus Network: Lane Change")
#ax1.tick_params(axis='y', labelcolor=color)
ax1.tick_params(axis='y')
ax1.set_ylim(LaneChangeLower,LaneChangeHigh)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
#x2.set_ylabel('Dwell Time', color=color)
ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
DL_CAB = ax2.plot(t, DL_CAB_2700, color="blue", label = "CABs Network: Dwell Time")
DL_Bus = ax2.plot(t, DL_Bus_2700, color="aqua", label = "Bus Network: Dwell Time")

#ax2.tick_params(axis='y', labelcolor=color)
ax2.tick_params(axis='y', size=20)
ax2.set_ylim(DwellTimeLower,DwellTimeHigh)


# added these three lines
lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))



fig2.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %% [markdown]
# # 30-45 Minutes

# %%
fig3, ax1 = plt.subplots(figsize=(8,6))


ax1.set_title("30-45 Minutes", fontweight = "bold", fontsize = 15)
#color = 'tab:red'
ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
#ax1.set_ylabel('Number of Lane Change', color=color)
ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
LN_CAB = ax1.plot(t, LN_CAB_3600, color="red", label = "CABs Network: Lane Change")
LN_Bus = ax1.plot(t, LN_Bus_3600, color="coral", label = "Bus Network: Lane Change")
#ax1.tick_params(axis='y', labelcolor=color)
ax1.tick_params(axis='y')
ax1.set_ylim(LaneChangeLower,LaneChangeHigh)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
#x2.set_ylabel('Dwell Time', color=color)
ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
DL_CAB = ax2.plot(t, DL_CAB_3600, color="blue", label = "CABs Network: Dwell Time")
DL_Bus = ax2.plot(t, DL_Bus_3600, color="aqua", label = "Bus Network: Dwell Time")

#ax2.tick_params(axis='y', labelcolor=color)
ax2.tick_params(axis='y', size=20)
ax2.set_ylim(DwellTimeLower,DwellTimeHigh)


# added these three lines
lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))


#ax1.legend(loc=0)
#ax2.legend(loc=4)

#ax1.legend()
#ax2.legend()

fig3.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %% [markdown]
# # 45-60 Minutes

# %%
fig4, ax1 = plt.subplots(figsize=(8,6))


ax1.set_title("45-60 Minutes", fontweight = "bold", fontsize = 15)
#color = 'tab:red'
ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
#ax1.set_ylabel('Number of Lane Change', color=color)
ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
LN_CAB = ax1.plot(t, LN_CAB_4500, color="red", label = "CABs Network: Lane Change")
LN_Bus = ax1.plot(t, LN_Bus_4500, color="coral", label = "Bus Network: Lane Change")
#ax1.tick_params(axis='y', labelcolor=color)
ax1.tick_params(axis='y')
ax1.set_ylim(LaneChangeLower,LaneChangeHigh)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#color = 'tab:blue'
#x2.set_ylabel('Dwell Time', color=color)
ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
DL_CAB = ax2.plot(t, DL_CAB_4500, color="blue", label = "CABs Network: Dwell Time")
DL_Bus = ax2.plot(t, DL_Bus_4500, color="aqua", label = "Bus Network: Dwell Time")

#ax2.tick_params(axis='y', labelcolor=color)
ax2.tick_params(axis='y', size=20)
ax2.set_ylim(DwellTimeLower,DwellTimeHigh)


# added these three lines
lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))


#ax1.legend(loc=0)
#ax2.legend(loc=4)

#ax1.legend()
#ax2.legend()

fig4.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %% [markdown]
# fig, axs = plt.subplots(2, 2)
# axs[0, 0].fig4, ax1 = plt.subplots(figsize=(8,6))
# ax1.set_title("45-60 Minutes", fontweight = "bold", fontsize = 15)
# #color = 'tab:red'
# ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
# #ax1.set_ylabel('Number of Lane Change', color=color)
# ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
# LN_CAB = ax1.plot(t, LN_CAB_4500, color="red", label = "CABs Network: Lane Change")
# LN_Bus = ax1.plot(t, LN_Bus_4500, color="coral", label = "Bus Network: Lane Change")
# #ax1.tick_params(axis='y', labelcolor=color)
# ax1.tick_params(axis='y')
# ax1.set_ylim(LaneChangeLower,LaneChangeHigh)
#
# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
#
# #color = 'tab:blue'
# #x2.set_ylabel('Dwell Time', color=color)
# ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
# DL_CAB = ax2.plot(t, DL_CAB_4500, color="blue", label = "CABs Network: Dwell Time")
# DL_Bus = ax2.plot(t, DL_Bus_4500, color="aqua", label = "Bus Network: Dwell Time")
#
# #ax2.tick_params(axis='y', labelcolor=color)
# ax2.tick_params(axis='y', size=20)
# ax2.set_ylim(DwellTimeLower,DwellTimeHigh)
#
#
# # added these three lines
# lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
# labs = [l.get_label() for l in lns]
# ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))
#
#
# fig4.tight_layout()  # otherwise the right y-label is slightly clipped
#
#
# axs[0, 0].set_title('Axis [0, 0]')
# axs[0, 1].fig4, ax1 = plt.subplots(figsize=(8,6))
# ax1.set_title("45-60 Minutes", fontweight = "bold", fontsize = 15)
# #color = 'tab:red'
# ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
# #ax1.set_ylabel('Number of Lane Change', color=color)
# ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
# LN_CAB = ax1.plot(t, LN_CAB_4500, color="red", label = "CABs Network: Lane Change")
# LN_Bus = ax1.plot(t, LN_Bus_4500, color="coral", label = "Bus Network: Lane Change")
# #ax1.tick_params(axis='y', labelcolor=color)
# ax1.tick_params(axis='y')
# ax1.set_ylim(LaneChangeLower,LaneChangeHigh)
#
# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
#
# #color = 'tab:blue'
# #x2.set_ylabel('Dwell Time', color=color)
# ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
# DL_CAB = ax2.plot(t, DL_CAB_4500, color="blue", label = "CABs Network: Dwell Time")
# DL_Bus = ax2.plot(t, DL_Bus_4500, color="aqua", label = "Bus Network: Dwell Time")
#
# #ax2.tick_params(axis='y', labelcolor=color)
# ax2.tick_params(axis='y', size=20)
# ax2.set_ylim(DwellTimeLower,DwellTimeHigh)
#
#
# # added these three lines
# lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
# labs = [l.get_label() for l in lns]
# ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))
#
#
# fig4.tight_layout()
# axs[0, 1].set_title('Axis [0, 1]')
# axs[1, 0].fig4, ax1 = plt.subplots(figsize=(8,6))
# ax1.set_title("45-60 Minutes", fontweight = "bold", fontsize = 15)
# #color = 'tab:red'
# ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
# #ax1.set_ylabel('Number of Lane Change', color=color)
# ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
# LN_CAB = ax1.plot(t, LN_CAB_4500, color="red", label = "CABs Network: Lane Change")
# LN_Bus = ax1.plot(t, LN_Bus_4500, color="coral", label = "Bus Network: Lane Change")
# #ax1.tick_params(axis='y', labelcolor=color)
# ax1.tick_params(axis='y')
# ax1.set_ylim(LaneChangeLower,LaneChangeHigh)
#
# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
#
# #color = 'tab:blue'
# #x2.set_ylabel('Dwell Time', color=color)
# ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
# DL_CAB = ax2.plot(t, DL_CAB_4500, color="blue", label = "CABs Network: Dwell Time")
# DL_Bus = ax2.plot(t, DL_Bus_4500, color="aqua", label = "Bus Network: Dwell Time")
#
# #ax2.tick_params(axis='y', labelcolor=color)
# ax2.tick_params(axis='y', size=20)
# ax2.set_ylim(DwellTimeLower,DwellTimeHigh)
#
#
# # added these three lines
# lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
# labs = [l.get_label() for l in lns]
# ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))
#
#
# fig4.tight_layout()
# axs[1, 0].set_title('Axis [1, 0]')
# axs[1, 1].fig4, ax1 = plt.subplots(figsize=(8,6))
# ax1.set_title("45-60 Minutes", fontweight = "bold", fontsize = 15)
# #color = 'tab:red'
# ax1.set_xlabel('% CAV Penetration', fontweight = "bold", fontsize = 13)
# #ax1.set_ylabel('Number of Lane Change', color=color)
# ax1.set_ylabel('Number of Lane Change', fontweight = "bold", fontsize = 13)
# LN_CAB = ax1.plot(t, LN_CAB_4500, color="red", label = "CABs Network: Lane Change")
# LN_Bus = ax1.plot(t, LN_Bus_4500, color="coral", label = "Bus Network: Lane Change")
# #ax1.tick_params(axis='y', labelcolor=color)
# ax1.tick_params(axis='y')
# ax1.set_ylim(LaneChangeLower,LaneChangeHigh)
#
# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
#
# #color = 'tab:blue'
# #x2.set_ylabel('Dwell Time', color=color)
# ax2.set_ylabel('Dwell Time' , fontweight = "bold", fontsize = 13)# we already handled the x-label with ax1
# DL_CAB = ax2.plot(t, DL_CAB_4500, color="blue", label = "CABs Network: Dwell Time")
# DL_Bus = ax2.plot(t, DL_Bus_4500, color="aqua", label = "Bus Network: Dwell Time")
#
# #ax2.tick_params(axis='y', labelcolor=color)
# ax2.tick_params(axis='y', size=20)
# ax2.set_ylim(DwellTimeLower,DwellTimeHigh)
#
#
# # added these three lines
# lns = LN_CAB+LN_Bus+DL_CAB+DL_Bus
# labs = [l.get_label() for l in lns]
# ax1.legend(lns, labs, loc='lower center', bbox_to_anchor=(0.85, 1))
#
#
# fig4.tight_layout()
# axs[1, 1].set_title('Axis [1, 1]')
